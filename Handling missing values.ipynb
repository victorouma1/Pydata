# %%
import pandas as pd
import numpy as np

# %%
val1 = np.array([1,None,2,3])
val1
# Out:
# array([1, None, 2, 3], dtype=object)

# %%
# %timeit np.arange(156, dtype=int).sum()
# Out:
# 1.56 μs ± 29.8 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
# %timeit np.arange(156, dtype=object).sum()
# Out:
# 4.41 μs ± 173 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
val1.sum() # Unable to do sum due to None

# %%
val2 = np.array([1,np.nan,2,3])
val2
# Out:
# array([ 1., nan,  2.,  3.])

# %%
val2.sum()
# Out:
# np.float64(nan)

# %%
val2.min()
# Out:
# np.float64(nan)

# %%
np.nansum(val2), np.nanmin(val2)
# Out:
# (np.float64(6.0), np.float64(1.0))

# %%
x = pd.Series(range(2), dtype=int)  
x
# Out:
# 0    0
# 1    1
# dtype: int64

# %%
x[0] = None
x
# Out:
# 0    NaN
# 1    1.0
# dtype: float64

# %%
pd.Series([1,np.nan,2,None,3])
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# 4    3.0
# dtype: float64

# %% [markdown]
# Detecting null values

# %%
data = pd.Series([1,3,5,6,np.nan,'Hello',None])
data
# Out:
# 0        1
# 1        3
# 2        5
# 3        6
# 4      NaN
# 5    Hello
# 6     None
# dtype: object

# %%
data.isna()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6     True
# dtype: bool

# %%
data[data.notnull()]
# Out:
# 0        1
# 1        3
# 2        5
# 3        6
# 5    Hello
# dtype: object

# %%
data.dropna()
# Out:
# 0        1
# 1        3
# 2        5
# 3        6
# 5    Hello
# dtype: object

# %%
data
# Out:
# 0        1
# 1        3
# 2        5
# 3        6
# 4      NaN
# 5    Hello
# 6     None
# dtype: object

# %%
sum(data.isnull())
# Out:
# 2

# %%
df = pd.DataFrame([[1,np.nan,2],[2,3,5],[np.nan,6,7]])
df
# Out:
#      0    1  2
# 0  1.0  NaN  2
# 1  2.0  3.0  5
# 2  NaN  6.0  7

# %%
df.dropna()
# Out:
#      0    1  2
# 1  2.0  3.0  5

# %%
df.dropna(axis = 1)
# Out:
#    2
# 0  2
# 1  5
# 2  7

# %%
df[3] = np.nan
df
# Out:
#      0    1  2   3
# 0  1.0  NaN  2 NaN
# 1  2.0  3.0  5 NaN
# 2  NaN  6.0  7 NaN

# %%
df.dropna(axis = 'columns',how='all')
# Out:
#      0    1  2
# 0  1.0  NaN  2
# 1  2.0  3.0  5
# 2  NaN  6.0  7

# %%
df.dropna(axis = 'columns',how='any')
# Out:
#    2
# 0  2
# 1  5
# 2  7

# %%
data = pd.Series([1, np.nan, 2, None, 3], index=list('abcde'), dtype='Int32')
data
# Out:
# a       1
# b    <NA>
# c       2
# d    <NA>
# e       3
# dtype: Int32

# %%
data.fillna(0)
# Out:
# a    1
# b    0
# c    2
# d    0
# e    3
# dtype: Int32

# %%
data.ffill()
# Out:
# a    1
# b    1
# c    2
# d    2
# e    3
# dtype: Int32

# %%
data.bfill()
# Out:
# a    1
# b    2
# c    2
# d    3
# e    3
# dtype: Int32
